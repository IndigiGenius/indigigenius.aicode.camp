# %% [markdown]
# # Turtle Challenges
#
# Let's put our programming to the test! In this notebook, we'll try to complete challenges with a partner.
#
# You will run this code in VS Code using the scripts found in this folder.
# - `turtle_challenge_1.py`
# - `turtle_challenge_2.py`
# - `turtle_challenge_3.py`
# - `turtle_challenge_4.py`
#
# ### Available Commands
# 1. t.left(n), t.right(n): Turn the turtle n degrees to the left or to the right
# 2. t.forward(n): Move the turtle n units forward
# 3. t.penup(): Moves following this command will not draw on the screen
# 4. t.pendown(): "Puts the pen back down" after a t.penup() command
# 5. t.pencolor(color_string): Changes the pen color to the given color_string
# 6. t.home(): Returns Turtle to the (0, 0) location

# %% [markdown]
# ## Challenge 1: Squares in a Grid
#
# For this first challenge, draw 9 squares in a 3x3 grid. It should look something like the picture below.
#
# How can you simplify your code to accomplish this task in a readable way? In a concise way? Are loops appropriate here? Are functions?
#
# ![image.png](attachment:image.png)

# %%
from mobilechelonian import Turtle

t = Turtle()
# YOUR CODE HERE

# %% [markdown]
# ## New Commands!
#
# For the rest of the exercises, feel free to use these commands:
#
# 1. t.setposition(x, y, bearing=None): Move the turtle to (x, y) and face (bearing)
# 2. t.circle(radius, extent=360): From the current position, draw a circle with the given (radius). (Extent) determines how much of the circle is drawn.

# %% [markdown]
# ## Challenge 2: Circles in a Grid
#
# For this first challenge, draw 8 circles as you would in a 3x3 grid, but leave one missing. It should look something like the picture below.
#
# ![image-2.png](attachment:image-2.png)

# %%
from mobilechelonian import Turtle

t = Turtle()
# YOUR CODE HERE

# %% [markdown]
# ## Challenge 3: Draw an N Sided Star
#
# Can you create a function that will result in your turtle drawing an N-sided star?
#
# 5 Point Example
# ![image.png](attachment:image.png)
#
# 6 Point Example
# ![image-2.png](attachment:image-2.png)

# %%
from mobilechelonian import Turtle

t = Turtle()

def draw_n_sided_star(t, n):
    # YOUR CODE HERE

# %% [markdown]
# ## Challenge 4: Draw a Star Quilt!
#
# Maybe the ultimate challenge. Can your turtle draw the outline for a starquilt?
#
# ![image.png](attachment:image.png)

# %%
import turtle

t = Turtle()
# YOUR CODE HERE

# %%
turtle.Turtle?
