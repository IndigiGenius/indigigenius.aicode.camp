# %% [markdown]
# # Working with Datasets

# %% [markdown]
# Steps for Getting Started with Data Science.
# This guide is for working with: week_one_final_project.ipynb
#
#
# ## What we're trying to do:
# We want to create a model that answers a question about some recorded results, based on the other information in the data (features/columns), that isn't easily understood just from looking at the data.
#
# For example, what features of your life, explain your grades?
#
# target:
# * grades
#
# possible features:
# * sleep
# * attendance
# * tardies
# * absences
# * study time
# * missing assignments
# * time on extra curricular activies
# * how often you eat
# * commute times
# * commute distance
# * life circumstances

# %% [markdown]
# ## Steps to get started
#
# 1. If your notebook is in a bad state, "discard changes" in GitHub Desktop. Or pull from a fresh copy from [https://github.com/IndigiGenius/indigigenius.aicode.camp](https://github.com/IndigiGenius/indigigenius.aicode.camp).
#
# 1. Download your dataset (possibly from Kaggle [https://www.kaggle.com/datasets](https://www.kaggle.com/datasets)).
#    A nicer dataset to work with might have these attributes:
#     * is a CSV file
#     * something we want to target (ex: grades, revenue, cost, salary, something continuous and a number)
#       * what we mean is something that the other columns can help explain where that number came from
#     * A lot of numeric data
#     * clear simple text/content, that can then be transformed using helpers.
#
# 1. Extract the data if it came in a zip file.
#
# 1. Move that dataset to the same working directory as your notebook.
#    + *(GitHub Folder)\indigigenius.aicode.camp\01-python-and-data-science\notebooks\4 - Day Four*
#
# 1. Change the name of the file being used to our new file's name.
#    For example: if the file's name is `spotify_dataset.csv`, that is what we need inside of the code in our jupyter notebook (week_one_final_project.ipynb) for the line below.
#    `spotify_data = pd.read_csv("spotify_dataset.csv")`
#    Note: the variable name (`spotify_data`) does need to match, but that is the variable we use in the notebook.
#
# 1. whatever you set your variable to, such as `spotify_data`above, be sure that's what you are using in the notebook. So if you changed that varible name from `netflix_data` to `spotify_data`, replace everything that is `netflix_data` with `spotify_data`

# %% [markdown]
# ## How can I select a dataset?
#
# Examples of datasets that work well:
#  1. [Most Streamed Spotify Songs 2024](https://www.kaggle.com/datasets/nelgiriyewithana/most-streamed-spotify-songs-2024)
#     * Target: All Time Rank
#  1. [Top 100 Youtube Channels in the World](https://www.kaggle.com/datasets/mayankanand2701/top-1000-youtube-channels-in-the-world)
#     * Target: Subscribers
#
#
# Examples of simpler datasets that can be used to make a point:
#  1. [Fortune Top 1000 Companies by Revenue 2022](https://www.kaggle.com/datasets/surajjha101/fortune-top-1000-companies-by-revenue-2022)
#     * Target: Revenue
#     * Reason: A lot of the data readily explains the revenue, and the question of how they earned that revenue is not as interesting. However, you could use three features to explain the revenue.
#  1. [Film Genre Statistics](https://www.kaggle.com/datasets/thedevastator/film-genre-statistics)
#     * Target: Inflation-Adjusted Gross
#     * Reason: We have a good amount of data to use features to explain how much money a film genre can make, but there are limited columns with data.
#
# Examples of datasets that don't work (or are less useful for feature engineering):
#  1. [best-selling-books](https://www.kaggle.com/datasets/drahulsingh/best-selling-books)
#     * Reason: It just lists data, that we can't really use to explain something about a ranking/score/sales
#
# Some suggestions for finding good datasets:
# * Has 'all time rank' in the title, or something with 'rankings/scores'.

# %% [markdown]
# ## How to put your data in the right folder
#
# 1. Download it
#    ![image.png](attachment:09bd3ff9-a3ab-4b39-b868-1b48bf10417f.png)
#
# 1. Find it where you downloaded and click on the folder icon next to the file.
#    ![image.png](attachment:9bfd6d17-e86f-48e7-af0a-96eeea5884c5.png)
#
# 1. In the folder where you downloaded the file, right click on the file and select `Extract All`. This will create a new folder, not a zip file, where you can access the .CSV (or Comma Separated Values) file.
#    ![image.png](attachment:b19c90ee-c85a-40a2-97f3-1f402cd6d2db.png)
#
# 1. Open the folder, copy the file using `CTRL + C`, or select the file and hit the `Copy` button.
#    ![image.png](attachment:4dfa2f2b-f633-4f46-b362-f57b3874f5fe.png)
#
# 1. Now we want to put this file in our GitHub folder )*(GitHub Folder)\indigigenius.aicode.camp\01-python-and-data-science\notebooks\4 - Day Four*). But we need to find that first.
#
# 1. Open GitHub Desktop, use the `Repository` menu, and select `Show in Explorer`
#    <img src="attachment:0b4776e0-c2dc-49b0-a73e-1ab656480be1.png" style="max-height: 50px;">
#
# 1. Your GitHub folder for this repository should show up in Windows, and now you want to navitate the *4 - Day Four* folder.
#    1. Open on `01-python-and-data-science`
#       ![image.png](attachment:453570e0-bdfd-4588-9c9c-975c81e5691f.png)
#    1. Open `notebooks`
#       ![image.png](attachment:c75f45d4-cb19-4241-af10-35bf07575cbd.png)
#    1. Open `4 - Day Four`
#       ![image.png](attachment:93a79990-28a9-401a-ae03-5829e0400454.png)
#    1. Paste your file in `4 - Day Four` using `CTRL + V` or the Paste button
#       <img src="![image.png](attachment:1ae48ccb-5474-498b-83a7-5cb0294415c7.png)" style="max-height: 50px;">
