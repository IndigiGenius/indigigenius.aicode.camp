# %%
import turtle

# now let's take a look at the parameters used for the turtle.Turtle class
help(turtle.Turtle)

# %% [markdown]
# We can see that the parameters to create a turtle as we have been using it are:
# 1. shape='classic'
# 2. undobuffersize=1000
# 3. visible=True
#
# To extend the class, we will also need to pass in `self` as the first parameter.
#
# The code below sets the the *dunder* or double underscore `__init__` function to use these parameters, as well as the `self` parameter first.
#
# **The Challenge:**
# The original turtle class we have been working with has a `circle(radius)` method, but not a `square` method, there one below in our extended `Turtle_Extended`. Write the code to create a
# `rectangle(center_x, center_y, side_length_1, side_length_2)` method.

# %%
import turtle

class Turtle_Extended(turtle.Turtle):
    def __init__(self, shape='classic', undobuffersize=1000, visible=True):
        super().__init__(shape, undobuffersize, visible)

    # put your method here. ensure that the tabs are correct to be included within the Turtle_Extended class block
    def square(self, center_x, center_y, side_length=20):
        self.penup()
        # go to the top left corner of the square I want to draw
        top_left_x = center_x - side_length/2 # calculate how far left from the center I need to be (negative x)
        top_left_y = center_y + side_length/2 # calculate how far up from the center I need to be (positive y)
        t.setposition(top_left_x, top_left_y) # go to that top left corner spot
        # go to the top left corner of the square, split the length in half to get there, you're in the center now
    
        # now, face east (0 = east, 90 = north, 180 = west, 270 = south)
        self.setheading(0)
        # I'm where I want to be in the top left corner of the square I want to draw and facing east
        # put the pen down now and draw my square
        self.pendown()
        for side in range(4):
            t.forward(side_length)
            t.right(90)
        
        # put the pen up
        self.penup()
    
window = turtle.Screen()
window.setup(width=800, height=800)

t = Turtle_Extended()

t.square(-75, 0, 50)
t.square(-75, 75, 50)
t.square(-75, -75, 50)
t.square(0, 0, 50)
t.square(0, 75, 50)
t.square(0, -75, 50)
t.square(75, 0, 50)
t.square(75, 75, 50)
t.square(75, -75, 50)
t.square(0, 0, 250)

turtle.mainloop()
