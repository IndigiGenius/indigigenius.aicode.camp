# %%
# %matplotlib inline

# %%
import numpy as np

import h5py
import pprint
import time
import torch
import torchvision

import matplotlib.pyplot as plt
import torch.nn.functional as F
import torchvision.transforms as T

# %%
def show_random_image(train_ds, class_list=None):
    num = torch.randint(low=0, high=len(train_ds), size=(1,)).item()

    image, label = train_ds[num]
    image = image.numpy().transpose((1, 2, 0))
        
    if class_list:
        label = class_list[label]
        
    plt.title(label)
    plt.imshow(image)

# %%
def get_size(data):
    image, _ = data
    channels, height, width = image.shape
    return {'channels': channels, 'height': height, 'width': width}

# %%
cifar100_names = ['apple', 'aquarium_fish', 'baby', 'bear', 'beaver',
                  'bed', 'bee', 'beetle', 'bicycle', 'bottle',
                  'bowl', 'boy', 'bridge', 'bus', 'butterfly',
                  'camel', 'can', 'castle', 'caterpillar', 'cattle',
                  'chair', 'chimpanzee', 'clock', 'cloud', 'cockroach',
                  'couch', 'crab', 'crocodile', 'cup', 'dinosaur',
                  'dolphin', 'elephant', 'flatfish', 'forest', 'fox',
                  'girl', 'hamster', 'house', 'kangaroo', 'keyboard',
                  'lamp', 'lawn_mower', 'leopard', 'lion', 'lizard',
                  'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain',
                  'mouse', 'mushroom', 'oak_tree', 'orange', 'orchid',
                  'otter', 'palm_tree', 'pear', 'pickup_truck', 'pine_tree',
                  'plain', 'plate', 'poppy', 'porcupine', 'possum',
                  'rabbit', 'raccoon', 'ray', 'road', 'rocket',
                  'rose', 'sea', 'seal', 'shark', 'shrew',
                  'skunk', 'skyscraper', 'snail', 'snake', 'spider',
                  'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 'table',
                  'tank', 'telephone', 'television', 'tiger', 'tractor',
                  'train', 'trout', 'tulip', 'turtle', 'wardrobe',
                  'whale', 'willow_tree', 'wolf', 'woman', 'worm']

# %%
cifar100_train_ds = torchvision.datasets.CIFAR100(root='../data',
                                       train=True,
                                       transform=T.ToTensor(),
                                       download=True)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ../data/cifar-100-python.tar.gz
# 169001984it [00:05, 29812807.05it/s]
# Extracting ../data/cifar-100-python.tar.gz to ../data

# %%
get_size(cifar100_train_ds[10])
# Out:
# {'channels': 3, 'height': 32, 'width': 32}

# %%
show_random_image(cifar100_train_ds, class_list=cifar100_names)

# %%
fashionmnist_train_ds = torchvision.datasets.FashionMNIST(root='../data',
                                                          train=True,
                                                          transform=T.ToTensor(),
                                                          download=True)

# %%
fmnist_classes = ['t-shirt/top', 'trouser', 'pullover', 'dress', 'coat',
                  'sandal', 'shirt', 'sneaker', 'bag', 'ankle boot']

# %%
show_random_image(fashionmnist_train_ds, fmnist_classes)

# %%
country211_train_ds = torchvision.datasets.Country211(root='../data',
                                                      split='train',
                                                      transform=T.ToTensor(),
                                                      download=True)
# Out:
# Downloading https://openaipublic.azureedge.net/clip/data/country211.tgz to ../data/country211.tgz
#   2%|█                                                            | 190496768/11000241947 [00:06<06:25, 28009142.81it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 country211_train_ds = torchvision.datasets.Country211(root='../data',
#       2                                                       split='train',
#       3                                                       transform=T.ToTensor(),
#       4                                                       download=True)
#
# File /opt/conda/lib/python3.8/site-packages/torchvision/datasets/country211.py:44, in Country211.__init__(self, root, split, transform, target_transform, download)
#      41 self._base_folder = root / "country211"
#      43 if download:
# ---> 44     self._download()
#      46 if not self._check_exists():
#      47     raise RuntimeError("Dataset not found. You can use download=True to download it")
#
# File /opt/conda/lib/python3.8/site-packages/torchvision/datasets/country211.py:58, in Country211._download(self)
#      56 if self._check_exists():
#      57     return
# ---> 58 download_and_extract_archive(self._URL, download_root=self.root, md5=self._MD5)
#
# File /opt/conda/lib/python3.8/site-packages/torchvision/datasets/utils.py:430, in download_and_extract_archive(url, download_root, extract_root, filename, md5, remove_finished)
#     427 if not filename:
#     428     filename = os.path.basename(url)
# --> 430 download_url(url, download_root, filename, md5)
#     432 archive = os.path.join(download_root, filename)
#     433 print(f"Extracting {archive} to {extract_root}")
#
# File /opt/conda/lib/python3.8/site-packages/torchvision/datasets/utils.py:141, in download_url(url, root, filename, md5, max_redirect_hops)
#     139 try:
#     140     print("Downloading " + url + " to " + fpath)
# --> 141     _urlretrieve(url, fpath)
#     142 except (urllib.error.URLError, OSError) as e:  # type: ignore[attr-defined]
#     143     if url[:5] == "https":
#
# File /opt/conda/lib/python3.8/site-packages/torchvision/datasets/utils.py:35, in _urlretrieve(url, filename, chunk_size)
#      33 with urllib.request.urlopen(urllib.request.Request(url, headers={"User-Agent": USER_AGENT})) as response:
#      34     with tqdm(total=response.length) as pbar:
# ---> 35         for chunk in iter(lambda: response.read(chunk_size), ""):
#      36             if not chunk:
#      37                 break
#
# File /opt/conda/lib/python3.8/site-packages/torchvision/datasets/utils.py:35, in _urlretrieve.<locals>.<lambda>()
#      33 with urllib.request.urlopen(urllib.request.Request(url, headers={"User-Agent": USER_AGENT})) as response:
#      34     with tqdm(total=response.length) as pbar:
# ---> 35         for chunk in iter(lambda: response.read(chunk_size), ""):
#      36             if not chunk:
#      37                 break
#
# File /opt/conda/lib/python3.8/http/client.py:459, in HTTPResponse.read(self, amt)
#     456 if amt is not None:
#     457     # Amount is given, implement using readinto
#     458     b = bytearray(amt)
# --> 459     n = self.readinto(b)
#     460     return memoryview(b)[:n].tobytes()
#     461 else:
#     462     # Amount is not given (unbounded read) so we must check self.length
#     463     # and self.chunked
#
# File /opt/conda/lib/python3.8/http/client.py:503, in HTTPResponse.readinto(self, b)
#     498         b = memoryview(b)[0:self.length]
#     500 # we do not use _safe_read() here because this may be a .will_close
#     501 # connection, and the user is reading more bytes than will be provided
#     502 # (for example, reading in 1k chunks)
# --> 503 n = self.fp.readinto(b)
#     504 if not n and b:
#     505     # Ideally, we would raise IncompleteRead if the content-length
#     506     # wasn't satisfied, but it might break compatibility.
#     507     self._close_conn()
#
# File /opt/conda/lib/python3.8/socket.py:669, in SocketIO.readinto(self, b)
#     667 while True:
#     668     try:
# --> 669         return self._sock.recv_into(b)
#     670     except timeout:
#     671         self._timeout_occurred = True
#
# File /opt/conda/lib/python3.8/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/conda/lib/python3.8/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
country_list = classes = [
    'Andorra',
    'United Arab Emirates',
    'Afghanistan',
    'Antigua and Barbuda',
    'Anguilla',
    'Albania',
    'Armenia',
    'Angola',
    'Antarctica',
    'Argentina',
    'Austria',
    'Australia',
    'Aruba',
    'Aland Islands',
    'Azerbaijan',
    'Bosnia and Herzegovina',
    'Barbados',
    'Bangladesh',
    'Belgium',
    'Burkina Faso',
    'Bulgaria',
    'Bahrain',
    'Benin',
    'Bermuda',
    'Brunei Darussalam',
    'Bolivia',
    'Bonaire, Saint Eustatius and Saba',
    'Brazil',
    'Bahamas',
    'Bhutan',
    'Botswana',
    'Belarus',
    'Belize',
    'Canada',
    'DR Congo',
    'Central African Republic',
    'Switzerland',
    "Cote d'Ivoire",
    'Cook Islands',
    'Chile',
    'Cameroon',
    'China',
    'Colombia',
    'Costa Rica',
    'Cuba',
    'Cabo Verde',
    'Curacao',
    'Cyprus',
    'Czech Republic',
    'Germany',
    'Denmark',
    'Dominica',
    'Dominican Republic',
    'Algeria',
    'Ecuador',
    'Estonia',
    'Egypt',
    'Spain',
    'Ethiopia',
    'Finland',
    'Fiji',
    'Falkland Islands',
    'Faeroe Islands',
    'France',
    'Gabon',
    'United Kingdom',
    'Grenada',
    'Georgia',
    'French Guiana',
    'Guernsey',
    'Ghana',
    'Gibraltar',
    'Greenland',
    'Gambia',
    'Guadeloupe',
    'Greece',
    'South Georgia and South Sandwich Is.',
    'Guatemala',
    'Guam',
    'Guyana',
    'Hong Kong',
    'Honduras',
    'Croatia',
    'Haiti',
    'Hungary',
    'Indonesia',
    'Ireland',
    'Israel',
    'Isle of Man',
    'India',
    'Iraq',
    'Iran',
    'Iceland',
    'Italy',
    'Jersey',
    'Jamaica',
    'Jordan',
    'Japan',
    'Kenya',
    'Kyrgyz Republic',
    'Cambodia',
    'St. Kitts and Nevis',
    'North Korea',
    'South Korea',
    'Kuwait',
    'Cayman Islands',
    'Kazakhstan',
    'Laos',
    'Lebanon',
    'St. Lucia',
    'Liechtenstein',
    'Sri Lanka',
    'Liberia',
    'Lithuania',
    'Luxembourg',
    'Latvia',
    'Libya',
    'Morocco',
    'Monaco',
    'Moldova',
    'Montenegro',
    'Saint-Martin',
    'Madagascar',
    'Macedonia',
    'Mali',
    'Myanmar',
    'Mongolia',
    'Macau',
    'Martinique',
    'Mauritania',
    'Malta',
    'Mauritius',
    'Maldives',
    'Malawi',
    'Mexico',
    'Malaysia',
    'Mozambique',
    'Namibia',
    'New Caledonia',
    'Nigeria',
    'Nicaragua',
    'Netherlands',
    'Norway',
    'Nepal',
    'New Zealand',
    'Oman',
    'Panama',
    'Peru',
    'French Polynesia',
    'Papua New Guinea',
    'Philippines',
    'Pakistan',
    'Poland',
    'Puerto Rico',
    'Palestine',
    'Portugal',
    'Palau',
    'Paraguay',
    'Qatar',
    'Reunion',
    'Romania',
    'Serbia',
    'Russia',
    'Rwanda',
    'Saudi Arabia',
    'Solomon Islands',
    'Seychelles',
    'Sudan',
    'Sweden',
    'Singapore',
    'St. Helena',
    'Slovenia',
    'Svalbard and Jan Mayen Islands',
    'Slovakia',
    'Sierra Leone',
    'San Marino',
    'Senegal',
    'Somalia',
    'South Sudan',
    'El Salvador',
    'Sint Maarten',
    'Syria',
    'Eswatini',
    'Togo',
    'Thailand',
    'Tajikistan',
    'Timor-Leste',
    'Turkmenistan',
    'Tunisia',
    'Tonga',
    'Turkey',
    'Trinidad and Tobago',
    'Taiwan',
    'Tanzania',
    'Ukraine',
    'Uganda',
    'United States',
    'Uruguay',
    'Uzbekistan',
    'Vatican',
    'Venezuela',
    'British Virgin Islands',
    'United States Virgin Islands',
    'Vietnam',
    'Vanuatu',
    'Samoa',
    'Kosovo',
    'Yemen',
    'South Africa',
    'Zambia',
    'Zimbabwe',
]

# %%
show_random_image(country211_train_ds, country_list)

# %%
get_size(country211_train_ds[1])
# Out:
# {'channels': 3, 'height': 499, 'width': 333}

# %%
aircraft_train_ds = torchvision.datasets.FGVCAircraft(root='../data',
                                                      split='train',
                                                      annotation_level='family',
                                                      transform=T.ToTensor(),
                                                      download=True)
# Out:
# Downloading https://www.robots.ox.ac.uk/~vgg/data/fgvc-aircraft/archives/fgvc-aircraft-2013b.tar.gz to ./data/fgvc-aircraft-2013b.tar.gz
# 2753340416it [02:52, 15932210.75it/s]
# Extracting ./data/fgvc-aircraft-2013b.tar.gz to ./data

# %%
airplane_list = ['A300', 'A310', 'A320', 'A330', 'A340', 'A380', 'ATR-42',
                 'ATR-72', 'An-12', 'BAE 146', 'BAE-125', 'Beechcraft 1900',
                 'Boeing 707', 'Boeing 717', 'Boeing 727', 'Boeing 737',
                 'Boeing 747', 'Boeing 757', 'Boeing 767', 'Boeing 777',
                 'C-130', 'C-47', 'CRJ-200', 'CRJ-700', 'Cessna 172',
                 'Cessna 208', 'Cessna Citation', 'Challenger 600',
                 'DC-10', 'DC-3', 'DC-6', 'DC-8', 'DC-9', 'DH-82',
                 'DHC-1', 'DHC-6', 'DR-400', 'Dash 8', 'Dornier 328',
                 'EMB-120', 'Embraer E-Jet', 'Embraer ERJ 145',
                 'Embraer Legacy 600', 'Eurofighter Typhoon', 'F-16',
                 'F/A-18', 'Falcon 2000', 'Falcon 900', 'Fokker 100',
                 'Fokker 50', 'Fokker 70', 'Global Express', 'Gulfstream',
                 'Hawk T1', 'Il-76', 'King Air', 'L-1011', 'MD-11',
                 'MD-80', 'MD-90', 'Metroliner', 'PA-28', 'SR-20',
                 'Saab 2000', 'Saab 340', 'Spitfire', 'Tornado',
                 'Tu-134', 'Tu-154', 'Yak-42']

# %%
show_random_image(aircraft_train_ds, airplane_list)

# %%
get_size(aircraft_train_ds[0])
# Out:
# {'channels': 3, 'height': 695, 'width': 1024}

# %%
eurosat_train_ds = torchvision.datasets.EuroSAT(root='../data',
                                                transform=T.ToTensor(),
                                                download=True)
# Out:
# Downloading https://madm.dfki.de/files/sentinel/EuroSAT.zip to ../data/eurosat/EuroSAT.zip
# 94280704it [00:07, 12928247.20it/s]
# Extracting ../data/eurosat/EuroSAT.zip to ../data/eurosat

# %%
show_random_image(eurosat_train_ds, eurosat_train_ds.classes)

# %%
EMNIST_train_ds = torchvision.datasets.EMNIST(root='../data',
                                              split='letters',
                                              train=True,
                                              download=True,
                                              transform=T.ToTensor())
# Out:
# Downloading https://www.itl.nist.gov/iaui/vip/cs_links/EMNIST/gzip.zip to ../data/EMNIST/raw/gzip.zip
# 561754112it [00:29, 19120809.61it/s]
# Extracting ../data/EMNIST/raw/gzip.zip to ../data/EMNIST/raw

# %%
show_random_image(EMNIST_train_ds, EMNIST_train_ds.classes)

# %%
get_size(EMNIST_train_ds[9])
# Out:
# {'channels': 1, 'height': 28, 'width': 28}

# %%
KMNIST_train_ds = torchvision.datasets.KMNIST(root='../data',
                                              train=True,
                                              transform=T.ToTensor(),
                                              download=True)
# Out:
# Downloading http://codh.rois.ac.jp/kmnist/dataset/kmnist/train-images-idx3-ubyte.gz
# Downloading http://codh.rois.ac.jp/kmnist/dataset/kmnist/train-images-idx3-ubyte.gz to ../data/KMNIST/raw/train-images-idx3-ubyte.gz
# 18165760it [00:15, 1163669.38it/s]
# Extracting ../data/KMNIST/raw/train-images-idx3-ubyte.gz to ../data/KMNIST/raw
#
# Downloading http://codh.rois.ac.jp/kmnist/dataset/kmnist/train-labels-idx1-ubyte.gz
# Downloading http://codh.rois.ac.jp/kmnist/dataset/kmnist/train-labels-idx1-ubyte.gz to ../data/KMNIST/raw/train-labels-idx1-ubyte.gz
# 29696it [00:00, 198133.50it/s]
# Extracting ../data/KMNIST/raw/train-labels-idx1-ubyte.gz to ../data/KMNIST/raw
#
# Downloading http://codh.rois.ac.jp/kmnist/dataset/kmnist/t10k-images-idx3-ubyte.gz
# Downloading http://codh.rois.ac.jp/kmnist/dataset/kmnist/t10k-images-idx3-ubyte.gz to ../data/KMNIST/raw/t10k-images-idx3-ubyte.gz
# 3041280it [00:02, 1050574.97it/s]
# Extracting ../data/KMNIST/raw/t10k-images-idx3-ubyte.gz to ../data/KMNIST/raw
#
# Downloading http://codh.rois.ac.jp/kmnist/dataset/kmnist/t10k-labels-idx1-ubyte.gz
# Downloading http://codh.rois.ac.jp/kmnist/dataset/kmnist/t10k-labels-idx1-ubyte.gz to ../data/KMNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████████████████████████████████████████████████████████████████████| 5120/5120 [00:00<00:00, 3087239.29it/s]
# Extracting ../data/KMNIST/raw/t10k-labels-idx1-ubyte.gz to ../data/KMNIST/raw

# %%
show_random_image(KMNIST_train_ds, KMNIST_train_ds.classes)

# %%
get_size(KMNIST_train_ds[9])
# Out:
# {'channels': 1, 'height': 28, 'width': 28}

# %%
oxford_pets_train_ds = torchvision.datasets.OxfordIIITPet(root='../data',
                                                          split= 'trainval',
                                                          transform=T.ToTensor(),
                                                          download=True)

# %%
show_random_image(oxford_pets_train_ds, oxford_pets_train_ds.classes)

# %%
get_size(oxford_pets_train_ds[3])
# Out:
# {'channels': 3, 'height': 351, 'width': 500}

# %%
pcam_train_ds = torchvision.datasets.PCAM(root='../data',
                                          split='train',\
                                          transform=T.ToTensor(),
                                          download=True)
# Out:
# 2291it [00:00, 9725860.79it/s]
# ---------------------------------------------------------------------------
# BadGzipFile                               Traceback (most recent call last)
# Input In [28], in <cell line: 1>()
# ----> 1 pcam_train_ds = torchvision.datasets.PCAM(root='../data',
#       2                                           split='train',\
#       3                                           transform=T.ToTensor(),
#       4                                           download=True)
#
# File /opt/conda/lib/python3.8/site-packages/torchvision/datasets/pcam.py:92, in PCAM.__init__(self, root, split, transform, target_transform, download)
#      89 self._base_folder = pathlib.Path(self.root) / "pcam"
#      91 if download:
# ---> 92     self._download()
#      94 if not self._check_exists():
#      95     raise RuntimeError("Dataset not found. You can use download=True to download it")
#
# File /opt/conda/lib/python3.8/site-packages/torchvision/datasets/pcam.py:130, in PCAM._download(self)
#     128 archive_name = file_name + ".gz"
#     129 download_file_from_google_drive(file_id, str(self._base_folder), filename=archive_name, md5=md5)
# --> 130 _decompress(str(self._base_folder / archive_name))
#
# File /opt/conda/lib/python3.8/site-packages/torchvision/datasets/utils.py:372, in _decompress(from_path, to_path, remove_finished)
#     369 compressed_file_opener = _COMPRESSED_FILE_OPENERS[compression]
#     371 with compressed_file_opener(from_path, "rb") as rfh, open(to_path, "wb") as wfh:
# --> 372     wfh.write(rfh.read())
#     374 if remove_finished:
#     375     os.remove(from_path)
#
# File /opt/conda/lib/python3.8/gzip.py:292, in GzipFile.read(self, size)
#     290     import errno
#     291     raise OSError(errno.EBADF, "read() on write-only GzipFile object")
# --> 292 return self._buffer.read(size)
#
# File /opt/conda/lib/python3.8/gzip.py:479, in _GzipReader.read(self, size)
#     475 if self._new_member:
#     476     # If the _new_member flag is set, we have to
#     477     # jump to the next member, if there is one.
#     478     self._init_read()
# --> 479     if not self._read_gzip_header():
#     480         self._size = self._pos
#     481         return b""
#
# File /opt/conda/lib/python3.8/gzip.py:427, in _GzipReader._read_gzip_header(self)
#     424     return False
#     426 if magic != b'\037\213':
# --> 427     raise BadGzipFile('Not a gzipped file (%r)' % magic)
#     429 (method, flag,
#     430  self._last_mtime) = struct.unpack("<BBIxx", self._read_exact(8))
#     431 if method != 8:
#
# BadGzipFile: Not a gzipped file (b'<!')

# %%
show_random_image()
